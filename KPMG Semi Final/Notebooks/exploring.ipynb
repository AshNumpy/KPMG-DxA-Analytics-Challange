# %%
import pandas as pd 
import numpy as np 

path = '../Datasets/dataframe.csv'
df = pd.read_csv(path);df.head()
# Out:
#          Date  Omerli  Darlik  Elmali  Terkos  Alibey  Buyukcekmece  \
# 0  01-01-2017   81.07   72.94    0.52   44.45   56.18         33.13
# 1  01-02-2017   82.16   74.11    0.51   44.93   58.38         33.63
# 2  01-03-2017   82.63   74.59    0.51   45.09   59.26         33.63
# 3  01-04-2017   82.79   75.07    0.52   45.25   59.79         33.80
# 4  01-05-2017   82.94   75.49    0.52   45.57   60.42         33.80
#
#    Sazlidere  Kazandere  Pabucdere  Istrancalar
# 0      34.07      28.84      13.07        40.24
# 1      34.64      28.57      12.99        34.68
# 2      34.87      28.17      12.93        29.18
# 3      35.10      27.97      12.84        23.32
# 4      35.39      27.97      13.10        26.85

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

for i in df.columns[1:].tolist():
    df[i].plot()
    plt.savefig(f"../Images/{i}_plot.png")
    plt.clf()

# %%
corr = df.drop(['Date'],axis=1).corr()
plt.imshow(corr, cmap='coolwarm', interpolation='none')

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title('Correlation Matrix Heatmap')

plt.savefig("../Images/correlation_matrix.png")
plt.show()

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Omerli',
#  'Darlik',
#  'Elmali',
#  'Terkos',
#  'Alibey',
#  'Buyukcekmece',
#  'Sazlidere',
#  'Kazandere',
#  'Pabucdere',
#  'Istrancalar']
